# %% [markdown]
# # https://programmers.co.kr/learn/courses/30/lessons/12944

# %%
def solution(arr):
    return sum(arr) / len(arr)

# %%
print(solution([1,2,3,4])) # 2.5
print(solution([5,5])) # 5
# Out:
# 2.5
# 5.0

# %% [markdown]
# # 해설
# 배열 안의 모든 원소의 합을 배열 안의 원소의 개수로 나누어 주면 평균이 된다.
