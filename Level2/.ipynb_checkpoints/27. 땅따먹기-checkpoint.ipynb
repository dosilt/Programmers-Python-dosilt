# %% [markdown]
# # https://programmers.co.kr/learn/courses/30/lessons/12913

# %%
def solution(land):
    for i in range(len(land)-2, -1, -1):
        land[i][0] += max(land[i+1][1], land[i+1][2], land[i+1][3])
        land[i][1] += max(land[i+1][0], land[i+1][2], land[i+1][3])
        land[i][2] += max(land[i+1][0], land[i+1][1], land[i+1][3])
        land[i][3] += max(land[i+1][0], land[i+1][1], land[i+1][2])
    return max(land[0])

# %%
print(solution([[1,2,3,5],[5,6,7,8],[4,3,2,1]])) # 16
# Out:
# 16

# %% [markdown]
# # 해설
# 땅따먹기의 룰은 programmers 위에 링크를 이용하여 보면 됩니다.
#
# 풀이법은 아래부터 위로 같은 열의 숫자를 제외한 나머지 숫자와 더했을 때 가장 큰 수를 만들어 가면서
#
# start지점 까지 연산을 진행하면 된다. 기본적인 dp 풀이 방식이다,
