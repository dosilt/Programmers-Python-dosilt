# %% [markdown]
# # https://programmers.co.kr/learn/courses/30/lessons/12980

# %%
def solution(n):
    return bin(n).count('1')

# %%
print(solution(5)) # 2
print(solution(6)) # 2
print(solution(5000)) # 5
# Out:
# 2
# 2
# 5

# %% [markdown]
# # 해설
# 수학적인 해석이 많이 필요한 문제이다. 잘 생각해보면 2진법으로 변경 했을 때 1의 개수가
#
# 한칸씩 앞으로 가야되는데 필요한 횟수이다.
