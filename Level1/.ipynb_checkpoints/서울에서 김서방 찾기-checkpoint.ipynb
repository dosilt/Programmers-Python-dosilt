# %% [markdown]
# # https://programmers.co.kr/learn/courses/30/lessons/12919

# %%
def solution(seoul):
    return '김서방은 ' + str(seoul.index('Kim')) + '에 있다'

# %%
print(solution(['Jane', 'Kim'])) # 김서방은 1에 있다
# Out:
# 김서방은 1에 있다

# %% [markdown]
# # 해설
# Kim이라는 데이터의 index number를 구하여 문자열을 return 하는 문제이다.
