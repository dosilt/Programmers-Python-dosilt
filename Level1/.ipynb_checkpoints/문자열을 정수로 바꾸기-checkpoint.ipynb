# %% [markdown]
# # https://programmers.co.kr/learn/courses/30/lessons/12925

# %%
def solution(s):
    answer = int(s)
    return answer

# %%
solution('1234')
# Out:
# 1234

# %% [markdown]
# # 해설
# 문자열로 들어온 숫자를 숫자형 데이터로 바꾸기 위해선 int 혹은 float 함수를 이용한다.
