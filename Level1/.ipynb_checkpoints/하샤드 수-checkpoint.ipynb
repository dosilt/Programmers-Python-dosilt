# %% [markdown]
# # https://programmers.co.kr/learn/courses/30/lessons/12947

# %%
def solution(x):
    return True if x % sum(map(int, str(x))) == 0 else False

# %%
print(solution(10)) # True
print(solution(12)) # True
print(solution(11)) # False
print(solution(13)) # False
# Out:
# True
# True
# False
# False

# %% [markdown]
# # 해설
# 입력으로 받은 숫자를 문자열로 바꾸어 각각의 숫자를 더하는 연산을 진행하고 이 값으로 입력으로 받은 숫자가 나누어 떨어지면
# True를 return 하고 아니면 False를 return 한다
